# %%
# Import the dependencies.
import os
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Create a practice set of random latitude and longitude combinations.
x = [25.12903645, 25.92017388, 26.62509167, -59.98969384, 37.30571269]
y = [-67.59741259, 11.09532135, 74.84233102, -76.89176677, -61.13376282]
coordinates = zip(x, y)

# %%
# Use the tuple() function to display the latitude and longitude combinations.
for coordinate in coordinates:
    print(coordinate[0], coordinate[1])
# Out:
# 25.12903645 -67.59741259
# 25.92017388 11.09532135
# 26.62509167 74.84233102
# -59.98969384 -76.89176677
# 37.30571269 -61.13376282

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
#citipy = r"C:\Users\reske\Anaconda3\envs\PythonData\lib\site-packages\citipy"
#from citipy import citipy

# %%
import sys  
# !{sys.executable} -m pip install --user citipy
# Out:
# Requirement already satisfied: citipy in c:\users\reske\anaconda3\envs\pythondata\lib\site-packages (0.0.5)
# Requirement already satisfied: kdtree>=0.12 in c:\users\reske\anaconda3\envs\pythondata\lib\site-packages (from citipy) (0.16)

# %%
from citipy import citipy

# %%
# Use the tuple() function to display the latitude and longitude combinations.
for coordinate in coordinates:
    print(citipy.nearest_city(coordinate[0], coordinate[1]).city_name,
          citipy.nearest_city(coordinate[0], coordinate[1]).country_code)
# Out:
# loksa ee
# zheleznodorozhnyy ru
# butaritari ki
# ushtobe kz
# sambava mg
# nikolskoye ru
# riberalta bo
# hobart au
# mataura pf
# bethel us
# rikitea pf
# ust-ilimsk ru
# nakhon si thammarat th
# bambous virieux mu
# mys shmidta ru
# ushuaia ar
# la ronge ca
# saint-philippe re
# novikovo ru
# puerto ayora ec
# cape town za
# butaritari ki
# bengkulu id
# ribeira grande pt
# butembo cd
# ponta do sol cv
# anadyr ru
# bengkulu id
# ushuaia ar
# nome us
# butaritari ki
# rikitea pf
# qaanaaq gl
# mataura pf
# alta floresta br
# puerto ayora ec
# iqaluit ca
# carnarvon au
# kismayo so
# albany au
# arman ru
# chokurdakh ru
# santa maria cv
# ushuaia ar
# vallenar cl
# ushuaia ar
# ushuaia ar
# vigrestad no
# rikitea pf
# corpus christi us
# lebu cl
# new norfolk au
# sabzevar ir
# pasni pk
# deputatskiy ru
# hithadhoo mv
# marsh harbour bs
# taolanaro mg
# elbistan tr
# tura in
# illoqqortoormiut gl
# nikolskoye ru
# kaitangata nz
# saskylakh ru
# castro cl
# kaitangata nz
# cape town za
# katsuura jp
# kapaa us
# klaksvik fo
# khatanga ru
# atuona pf
# bardiyah ly
# chokurdakh ru
# atuona pf
# maceio br
# taolanaro mg
# cape town za
# georgetown sh
# saint-philippe re
# cherskiy ru
# bambous virieux mu
# cabedelo br
# gosainganj in
# ayagoz kz
# kashi cn
# shchelyayur ru
# farmington us
# cabo san lucas mx
# port elizabeth za
# jamestown sh
# kaliua tz
# colesberg za
# cabo san lucas mx
# chokurdakh ru
# vaini to
# ushuaia ar
# iqaluit ca
# new norfolk au
# busselton au
# dikson ru
# vung tau vn
# carnarvon au
# progreso mx
# sai buri th
# lompoc us
# cabo san lucas mx
# port lincoln au
# aljezur pt
# hay river ca
# luderitz na
# dunedin nz
# ribeira grande pt
# illoqqortoormiut gl
# whitehorse ca
# broken hill au
# bluff nz
# ust-tsilma ru
# sao filipe cv
# komsomolskiy ru
# busselton au
# qaanaaq gl
# ushuaia ar
# kodiak us
# ulagan ru
# kamenskoye ru
# victoria sc
# burica pa
# road town vg
# jining cn
# mitsamiouli km
# torbay ca
# tiksi ru
# vaini to
# kaitangata nz
# turan ru
# khatanga ru
# nikolskoye ru
# hermanus za
# tiksi ru
# vaini to
# busselton au
# mataura pf
# mikhaylovka kz
# rikitea pf
# east london za
# los llanos de aridane es
# bluff nz
# busselton au
# kruisfontein za
# taolanaro mg
# ushuaia ar
# vostok ru
# luis correia br
# luderitz na
# yamethin mm
# punta arenas cl
# bethel us
# thinadhoo mv
# visby se
# airai pw
# victoria sc
# barrow us
# narsaq gl
# bac lieu vn
# atuona pf
# bambous virieux mu
# bonthe sl
# pacific grove us
# vaini to
# new norfolk au
# new norfolk au
# busselton au
# rocha uy
# nikolskoye ru
# misratah ly
# sena madureira br
# jamestown sh
# tasiilaq gl
# baykit ru
# nishihara jp
# leningradskiy ru
# hermanus za
# arzgir ru
# hermanus za
# bolivar us
# homer us
# sorong id
# bluff nz
# punta arenas cl
# airai pw
# busselton au
# sobolevo ru
# cayenne gf
# saquena pe
# anadyr ru
# bargal so
# mataura pf
# castro cl
# mersing my
# zhangjiakou cn
# albany au
# kodiak us
# guerrero negro mx
# tondano id
# talnakh ru
# kulhudhuffushi mv
# qaanaaq gl
# thompson ca
# boa vista br
# busselton au
# albany au
# illoqqortoormiut gl
# atar mr
# katiola ci
# albany au
# dunedin nz
# hobart au
# quelimane mz
# kapaa us
# ekhabi ru
# norman wells ca
# tabiauea ki
# bambous virieux mu
# cape town za
# albany au
# jamestown sh
# kapaa us
# ushuaia ar
# punta arenas cl
# busselton au
# nikolskoye ru
# majene id
# bluff nz
# kapaa us
# fukue jp
# avarua ck
# bengkulu id
# butaritari ki
# illoqqortoormiut gl
# albany au
# bluff nz
# inta ru
# port hardy ca
# vaini to
# paamiut gl
# mahebourg mu
# barabinsk ru
# caravelas br
# ushuaia ar
# carutapera br
# margate za
# ushuaia ar
# hobart au
# provideniya ru
# hithadhoo mv
# launceston au
# atuona pf
# hilo us
# ribeira grande pt
# dikson ru
# punta arenas cl
# mataura pf
# san nicolas ph
# qaanaaq gl
# chokurdakh ru
# butaritari ki
# santa isabel do rio negro br
# margate za
# tungkang tw
# georgetown sh
# sao filipe cv
# taolanaro mg
# mecca sa
# kodiak us
# horta pt
# kruisfontein za
# mataura pf
# kapaa us
# rikitea pf
# samarai pg
# innisfail au
# dawlatabad af
# san carlos bo
# san patricio mx
# rikitea pf
# yellowknife ca
# yellowknife ca
# mar del plata ar
# myaundzha ru
# lebu cl
# cape town za
# ushuaia ar
# ushuaia ar
# bredasdorp za
# papara pf
# kahului us
# tianpeng cn
# bredasdorp za
# bredasdorp za
# padang id
# ushuaia ar
# gondanglegi id
# victoria sc
# banda aceh id
# daru pg
# bluff nz
# ulladulla au
# kaseda jp
# kaltasy ru
# kapaa us
# lewisporte ca
# la ronge ca
# mys shmidta ru
# krasnoselkup ru
# rikitea pf
# atuona pf
# victoria sc
# rawson ar
# chapais ca
# punta arenas cl
# rikitea pf
# rikitea pf
# iranshahr ir
# erenhot cn
# hobart au
# whitecourt ca
# rocha uy
# pangnirtung ca
# ushuaia ar
# albany au
# ushuaia ar
# tasiilaq gl
# punta arenas cl
# dudinka ru
# rikitea pf
# rikitea pf
# tarnos fr
# thinadhoo mv
# port hardy ca
# vaini to
# mao td
# jamestown sh
# east london za
# tuktoyaktuk ca
# dingle ie
# drayton valley ca
# mahebourg mu
# los llanos de aridane es
# mataura pf
# butaritari ki
# aksu cn
# busselton au
# uthal pk
# andijon uz
# jovellanos cu
# kapaa us
# kitimat ca
# belmonte br
# port alfred za
# hilo us
# san patricio mx
# jamestown sh
# atuona pf
# rikitea pf
# barrow us
# qaanaaq gl
# mar del plata ar
# karamea nz
# poltavka ru
# abha sa
# coquimbo cl
# saint-philippe re
# amderma ru
# kibala ao
# vestmannaeyjar is
# luganville vu
# brza palanka rs
# tiksi ru
# punta arenas cl
# barrow us
# umzimvubu za
# rikitea pf
# misratah ly
# barrow us
# kodiak us
# ostrovnoy ru
# bethel us
# port alfred za
# diego de almagro cl
# ushuaia ar
# punta arenas cl
# namibe ao
# barrow us
# rikitea pf
# pisco pe
# vaini to
# port macquarie au
# vikulovo ru
# butaritari ki
# vega de alatorre mx
# kita ml
# aklavik ca
# piacabucu br
# tevaitoa pf
# mlalo tz
# lompoc us
# tiksi ru
# russell nz
# tifton us
# turukhansk ru
# punta arenas cl
# siniscola it
# busselton au
# kalmunai lk
# taoudenni ml
# punta arenas cl
# richards bay za
# busselton au
# muros es
# ushuaia ar
# qaanaaq gl
# thompson ca
# hithadhoo mv
# isangel vu
# hermanus za
# kuytun cn
# yellowknife ca
# cape town za
# asau tv
# port elizabeth za
# ushuaia ar
# atuona pf
# bethel us
# saint-philippe re
# sao felix do xingu br
# kabala sl
# mataura pf
# severo-kurilsk ru
# taolanaro mg
# saint-chamond fr
# esperance au
# mont-dore nc
# busselton au
# west wendover us
# lagoa pt
# tuktoyaktuk ca
# umm lajj sa
# ushuaia ar
# punta arenas cl
# ancud cl
# severo-kurilsk ru
# baie-comeau ca
# chokurdakh ru
# atuona pf
# provideniya ru
# sydney au
# bethel us
# punta arenas cl
# namibe ao
# jizan sa
# ushuaia ar
# blackwater au
# chipinge zw
# tiznit ma
# attawapiskat ca
# albany au
# esso ru
# hobyo so
# mar del plata ar
# albany au
# amqui ca
# filadelfia py
# bethel us
# nikolskoye ru
# husavik is
# krasnoselkup ru
# clyde river ca
# sao felix do xingu br
# constitucion mx
# nikolskoye ru
# porto velho br
# hobart au
# rikitea pf
# atuona pf
# udachnyy ru
# rikitea pf
# kavaratti in
# new norfolk au
# bargal so
# khatanga ru
# iralaya hn
# carnarvon au
# fortuna us
# jamestown sh
# avarua ck
# port elizabeth za
# atuona pf
# tiksi ru
# berbera so
# yellowknife ca
# palmer us
# punta arenas cl
# rock sound bs
# menomonie us
# kapaa us
# mataura pf
# praia cv
# busselton au
# new norfolk au
# ushuaia ar
# vardo no
# puerto ayora ec
# kahului us
# nizhniy baskunchak ru
# tasiilaq gl
# fare pf
# vidim ru
# carnarvon au
# rikitea pf
# kuah my
# tumannyy ru
# kapaa us
# savannah bight hn
# sioux lookout ca
# cayenne gf
# hilo us
# khatanga ru
# ushuaia ar
# hobart au
# victoria point au
# hermanus za
# amderma ru
# laranjeiras do sul br
# saleaula ws
# bredasdorp za
# belaya gora ru
# bundaberg au
# alyangula au
# isangel vu
# saint-philippe re
# ushuaia ar
# khatanga ru
# nikolskoye ru
# mataura pf
# longyearbyen sj
# kotka fi
# saint-philippe re
# tuktoyaktuk ca
# mataura pf
# verkhniy rohachyk ua
# tiksi ru
# rikitea pf
# albany au
# ribeira grande pt
# acapulco mx
# bur gabo so
# ponta do sol cv
# los llanos de aridane es
# grindavik is
# barentsburg sj
# mogadishu so
# port alfred za
# rikitea pf
# rikitea pf
# verkhnevilyuysk ru
# ushuaia ar
# lorengau pg
# yellowknife ca
# bluff nz
# ribeira grande pt
# praia da vitoria pt
# bremerton us
# taseyevo ru
# albany au
# smithers ca
# pangnirtung ca
# bluff nz
# huarmey pe
# taolanaro mg
# castro cl
# castro cl
# beringovskiy ru
# dicabisagan ph
# busselton au
# vaini to
# bundaberg au
# hilo us
# marcona pe
# mahebourg mu
# illoqqortoormiut gl
# cape town za
# atuona pf
# huarmey pe
# hermanus za
# carnarvon au
# rikitea pf
# ketchikan us
# qaanaaq gl
# almaznyy ru
# salalah om
# grindavik is
# kahului us
# haimen cn
# barbar sd
# busselton au
# daokou cn
# atuona pf
# vaini to
# qui nhon vn
# cabo san lucas mx
# tasiilaq gl
# atuona pf
# yellowknife ca
# barentsburg sj
# timberlake us
# hendijan ir
# palpa pe
# makakilo city us
# binzhou cn
# nynashamn se
# hermanus za
# chokurdakh ru
# rikitea pf
# taolanaro mg
# mataura pf
# carnarvon au
# geraldton au
# provideniya ru
# griffith au
# provideniya ru
# guerrero negro mx
# punta arenas cl
# albany au
# saskylakh ru
# kapaa us
# hasaki jp
# hilo us
# san patricio mx
# hermanus za
# ushuaia ar
# ribeira grande pt
# avera pf
# wilmington us
# ushuaia ar
# klaksvik fo
# mount isa au
# arraial do cabo br
# fortuna us
# zhigansk ru
# rikitea pf
# grand river south east mu
# tiksi ru
# hermanus za
# faanui pf
# hithadhoo mv
# bethel us
# antofagasta cl
# half moon bay us
# amfiklia gr
# touros br
# belushya guba ru
# kapaa us
# puerto rondon co
# avarua ck
# kodiak us
# kodiak us
# butaritari ki
# wajir ke
# atuona pf
# nizhniy tsasuchey ru
# flinders au
# bubaque gw
# mahebourg mu
# tautira pf
# busselton au
# kaitangata nz
# atuona pf
# pevek ru
# hasaki jp
# kyabe td
# mataura pf
# guiyang cn
# chokurdakh ru
# bognor regis gb
# dikson ru
# sentyabrskiy ru
# albany au
# bluff nz
# tibacuy co
# bredasdorp za
# tucuma br
# blackwater au
# broome au
# bubaque gw
# barrow us
# katsuura jp
# atuona pf
# upernavik gl
# dikson ru
# chuy uy
# esperance au
# hobart au
# darnah ly
# rikitea pf
# banda aceh id
# kaliua tz
# upernavik gl
# chuy uy
# borzya ru
# busselton au
# nouadhibou mr
# half moon bay us
# illoqqortoormiut gl
# port alfred za
# kasiri sl
# rikitea pf
# arraial do cabo br
# yellowknife ca
# kudahuvadhoo mv
# comodoro rivadavia ar
# yellowknife ca
# nome us
# lanxi cn
# mandera ke
# rikitea pf
# antalaha mg
# neustrelitz de
# ocho rios jm
# port alfred za
# college us
# pisco pe
# pak phanang th
# la palma pa
# ushuaia ar
# amapa br
# domna ru
# kudahuvadhoo mv
# bluff nz
# port hawkesbury ca
# kapaa us
# bredasdorp za
# attawapiskat ca
# severo-kurilsk ru
# saskylakh ru
# new norfolk au
# nizhneyansk ru
# hobart au
# chokurdakh ru
# hay river ca
# norman wells ca
# port alfred za
# cape town za
# bacolod ph
# thompson ca
# festus us
# butaritari ki
# cape town za
# rikitea pf
# mataura pf
# ordubad az
# cape town za
# tuktoyaktuk ca
# ushuaia ar
# bredasdorp za
# naron es
# punta arenas cl
# hobart au
# tiksi ru
# hirara jp
# arraial do cabo br
# kapaa us
# hermanus za
# rikitea pf
# port elizabeth za
# qaanaaq gl
# mar del plata ar
# saint-leu re
# tuktoyaktuk ca
# mataura pf
# lardos gr
# belmonte br
# puerto ayora ec
# hof no
# ushuaia ar
# airai pw
# hobart au
# odweyne so
# illoqqortoormiut gl
# cape town za
# port alfred za
# sibolga id
# bonthe sl
# iwanai jp
# ahuimanu us
# pangnirtung ca
# bafoulabe ml
# punta arenas cl
# makakilo city us
# punta arenas cl
# bambous virieux mu
# bella union uy
# barentsburg sj
# chuy uy
# ushuaia ar
# puerto lempira hn
# belushya guba ru
# atuona pf
# castro cl
# atuona pf
# tamandare br
# jaciara br
# manacapuru br
# kaitangata nz
# sinegorye ru
# shenjiamen cn
# hithadhoo mv
# ushuaia ar
# taolanaro mg
# butaritari ki
# camacha pt
# bluff nz
# cabo san lucas mx
# cabras it
# ushuaia ar
# mawlaik mm
# ahipara nz
# jamestown sh
# mataura pf
# blagodatnoye ru
# rikitea pf
# kushiro jp
# sentyabrskiy ru
# saskylakh ru
# mataura pf
# dentsville us
# rikitea pf
# egvekinot ru
# ushuaia ar
# busselton au
# torbay ca
# port hedland au
# tiksi ru
# tiksi ru
# busselton au
# butaritari ki
# bluff nz
# rassvet ru
# kaeo nz
# belushya guba ru
# shahrud ir
# lishu cn
# saint-philippe re
# longyearbyen sj
# pevek ru
# wabag pg
# severo-kurilsk ru
# manjakandriana mg
# sisimiut gl
# harindanga in
# san patricio mx
# shimoda jp
# bagotville ca
# sambava mg
# yayva ru
# kaitangata nz
# keti bandar pk
# awjilah ly
# caravelas br
# namibe ao
# illoqqortoormiut gl
# surt ly
# sawakin sd
# cape town za
# kamenskoye ru
# warqla dz
# coquimbo cl
# chuy uy
# norman wells ca
# poum nc
# asau tv
# tiksi ru
# hailar cn
# cape town za
# illoqqortoormiut gl
# mar del plata ar
# busselton au
# amderma ru
# illoqqortoormiut gl
# kamen-rybolov ru
# bredasdorp za
# bluff nz
# salalah om
# bluff nz
# ostrovnoy ru
# phan rang vn
# caravelas br
# torbay ca
# taolanaro mg
# cabo san lucas mx
# marataizes br
# ponta do sol cv
# puerto ayora ec
# ushuaia ar
# bonavista ca
# atuona pf
# coahuayana mx
# narsaq gl
# jamestown sh
# bredasdorp za
# atar mr
# kaitangata nz
# half moon bay us
# funehiki jp
# jamestown sh
# airai pw
# nizhneyansk ru
# kidal ml
# kaitangata nz
# chokurdakh ru
# bredasdorp za
# guadalupe y calvo mx
# kaitangata nz
# kapaa us
# jamestown sh
# qaanaaq gl
# tazovskiy ru
# ushuaia ar
# ushuaia ar
# hermanus za
# barrow us
# pangnirtung ca
# ponta do sol cv
# severo-kurilsk ru
# raja jang pk
# pakhni gr
# norman wells ca
# qaanaaq gl
# grindavik is
# rikitea pf
# san patricio mx
# lebu cl
# tilichiki ru
# bay roberts ca
# punta arenas cl
# albany au
# leningradskiy ru
# victoria sc
# yulara au
# sheregesh ru
# pangnirtung ca
# hermanus za
# zhumadian cn
# shelburne ca
# botou cn
# egvekinot ru
# ekhabi ru
# mgandu tz
# palabuhanratu id
# kahului us
# nikolskoye ru
# east london za
# mount isa au
# cape town za
# rikitea pf
# bluff nz
# longyearbyen sj
# belushya guba ru
# sibu my
# xunchang cn
# guarda pt
# provideniya ru
# kysyl-syr ru
# cape town za
# vaini to
# voh nc
# illoqqortoormiut gl
# klyuchi ru
# buraydah sa
# rikitea pf
# pangnirtung ca
# tikrit iq
# arraial do cabo br
# new norfolk au
# gusinoye ozero ru
# jamestown sh
# norman wells ca
# westport nz
# caravelas br
# durazno uy
# tocopilla cl
# nikolskoye ru
# barentsburg sj
# qaanaaq gl
# mount isa au
# punta arenas cl
# swellendam za
# east london za
# pishva ir
# leshukonskoye ru
# north bend us
# hobart au
# hilo us
# galiwinku au
# chokurdakh ru
# haradok by
# longyearbyen sj
# wiwili ni
# jamestown sh
# port elizabeth za
# faya td
# mogadishu so
# ushuaia ar
# ushuaia ar
# salalah om
# guerrero negro mx
# east london za
# atuona pf
# tikrit iq
# san jose gt
# chokurdakh ru
# middletown us
# bredasdorp za
# punta arenas cl
# cabedelo br
# vaini to
# cape town za
# hermanus za
# vaini to
# chernyshevskiy ru
# busselton au
# ushuaia ar
# kodiak us
# meulaboh id
# kapaa us
# grand gaube mu
# mataura pf
# khatanga ru
# mar del plata ar
# karaul ru
# albany au
# atuona pf
# atuona pf
# cape town za
# luanda ao
# qaanaaq gl
# port hawkesbury ca
# ushuaia ar
# kahului us
# kahului us
# taolanaro mg
# saldanha za
# poum nc
# port alfred za
# kudahuvadhoo mv
# yar-sale ru
# zhicheng cn
# mercedes ar
# ushtobe kz
# atuona pf
# saleaula ws
# almeirim br
# longyearbyen sj
# aklavik ca
# mys shmidta ru
# nyurba ru
# riyadh sa
# paamiut gl
# rikitea pf
# lagoa pt
# ushuaia ar
# taolanaro mg
# lorengau pg
# kapaa us
# burnie au
# puerto ayora ec
# leningradskiy ru
# east london za
# noumea nc
# melilla es
# touros br
# derzhavinsk kz
# kamsack ca
# lebu cl
# sungairaya id
# east london za
# saint-philippe re
# rikitea pf
# rikitea pf
# mataura pf
# liku wf
# pangnirtung ca
# iranshahr ir
# mataura pf
# victoria sc
# atbasar kz
# ushuaia ar
# rikitea pf
# pangnirtung ca
# hilo us
# dikson ru
# tasiilaq gl
# yellowknife ca
# pankrushikha ru
# srednekolymsk ru
# constitucion mx
# hermanus za
# aksu cn
# adrar dz
# lata sb
# puerto ayora ec
# barrow us
# uribia co
# hithadhoo mv
# thompson ca
# busselton au
# punta arenas cl
# nikolskoye ru
# pisco pe
# atuona pf
# yellowknife ca
# oktyabrskiy ru
# albany au
# scarborough gb
# araouane ml
# skagastrond is
# kemijarvi fi
# eureka us
# angoche mz
# tsihombe mg
# ushuaia ar
# tuktoyaktuk ca
# dikson ru
# mar del plata ar
# hermanus za
# yar-sale ru
# kazalinsk kz
# hilo us
# sobolevo ru
# nizhnyaya poyma ru
# upernavik gl
# norman wells ca
# kuhdasht ir
# lorengau pg
# pacific grove us
# kara-tyube ru
# narsaq gl
# kapaa us
# hilo us
# kaeo nz
# chuy uy
# mandalgovi mn
# dingle ie
# dingle ie
# yeppoon au
# atuona pf
# rocha uy
# hobart au
# pacific grove us
# laguna br
# paranaiba br
# hobart au
# biak id
# yellowknife ca
# busselton au
# samarai pg
# bajo baudo co
# albany au
# taolanaro mg
# yar-sale ru
# vaini to
# airai pw
# vaini to
# kodiak us
# vaini to
# kambove cd
# husavik is
# omboue ga
# hamilton bm
# bredasdorp za
# jamestown sh
# ilulissat gl
# wairoa nz
# paamiut gl
# el badari eg
# san cristobal ec
# torbay ca
# upernavik gl
# rikitea pf
# tucumcari us
# kungurtug ru
# yellowknife ca
# kavieng pg
# rawannawi ki
# bethel us
# pevek ru
# pangnirtung ca
# saint-georges gf
# kendari id
# bremervorde de
# vanderhoof ca
# scarborough gb
# kununurra au
# constitucion mx
# olinda br
# saint-philippe re
# san carlos de bariloche ar
# doctor pedro p. pena py
# busselton au
# vardo no
# saint-philippe re
# methoni gr
# kapaa us
# ponta do sol cv
# rikitea pf
# genhe cn
# ponta do sol cv
# chuy uy
# dikson ru
# faanui pf
# busselton au
# gornoye loo ru
# rikitea pf
# bluff nz
# bonfim br
# puerto ayora ec
# dekar bw
# busselton au
# barabinsk ru
# kadoma zw
# biltine td
# kismayo so
# mar del plata ar
# puerto ayora ec
# jamestown sh
# new norfolk au
# marv dasht ir
# hithadhoo mv
# rikitea pf
# vaini to
# port hardy ca
# provideniya ru
# kununurra au
# bluff nz
# riachao br
# cape town za
# mataura pf
# tura ru
# mahebourg mu
# hobart au
# mayo ca
# mataura pf
# vaini to
# taolanaro mg
# ushuaia ar
# busselton au
# baglung np
# severo-kurilsk ru
# sistranda no
# launceston au
# hambantota lk
# punta arenas cl
# namwala zm
# tsihombe mg
# kita ml
# jamestown sh
# etchoropo mx
# inta ru
# bredasdorp za
# khatanga ru
# skalistyy ru
# thompson ca
# khatanga ru
# hermanus za
# vaitupu wf
# guerrero negro mx
# sola vu
# bredasdorp za
# port elizabeth za
# atuona pf
# bredasdorp za
# tsihombe mg
# saint-philippe re
# hermanus za
# saleaula ws
# hun ly
# makakilo city us
# adrar dz
# saldanha za
# kapaa us
# new norfolk au
# mehamn no
# ribeira grande pt
# estelle us
# tabiauea ki
# nabire id
# changji cn
# havoysund no
# moranbah au
# kapaa us
# aksu cn
# touros br
# port alfred za
# hobart au
# east london za
# castro cl
# busselton au
# salalah om
# bluff nz
# puerto ayora ec
# cape town za
# albany au
# albany au
# punta arenas cl
# quatre cocos mu
# kapaa us
# arman ru
# sentyabrskiy ru
# anadyr ru
# healesville au
# arrifes pt
# yazman pk
# ushuaia ar
# solsvik no
# ruteng id
# nouadhibou mr
# la ronge ca
# kapaa us
# koslan ru
# cherskiy ru
# hermanus za
# itaituba br
# iqaluit ca
# ballina au
# yellowknife ca
# tiksi ru
# ushuaia ar
# coquimbo cl
# fallon us
# saint-pierre pm
# marsh harbour bs
# rio grande br
# bayaguana do
# airai pw
# ushuaia ar
# nabire id
# bambous virieux mu
# kapaa us
# tasiilaq gl
# ribeira grande pt
# sangar ru
# punta arenas cl
# carnarvon au
# mys shmidta ru
# lebu cl
# hobart au
# attawapiskat ca
# taolanaro mg
# batticaloa lk
# makasar id
# tuktoyaktuk ca
# sassandra ci
# rikitea pf
# zhezkazgan kz
# bredasdorp za
# hobart au
# avarua ck
# hervey bay au
# rikitea pf
# hermanus za
# bethel us
# vostok ru
# hobart au
# tuatapere nz
# thompson ca
# auch fr
# necochea ar
# busselton au
# san patricio mx
# belushya guba ru
# punta arenas cl
# tasiilaq gl
# mataura pf
# rikitea pf
# inhambane mz
# aras no
# aklavik ca
# alofi nu
# amapa br
# port alfred za
# cape town za
# hermanus za
# chokurdakh ru
# nikolskoye ru
# mayahi ne
# vila velha br
# rawannawi ki
# mataura pf
# shahdadkot pk
# whitehorse ca
# dawlatabad af
# braslav by
# severobaykalsk ru
# namibe ao
# namibe ao
# tsihombe mg
# hithadhoo mv
# tual id
# khatanga ru
# algiers dz
# bandar id
# dodoma tz
# longyearbyen sj
# vao nc
# pevek ru
# port lincoln au
# rikitea pf
# khatanga ru
# stornoway gb
# ancud cl
# roma au
# caravelas br
# buta cd
# nikolskoye ru
# albany au
# husavik is
# rikitea pf
# iqaluit ca
# kodiak us
# fort nelson ca
# chuy uy
# puerto ayora ec
# naze jp
# rikitea pf
# pojuca br
# atuona pf
# new norfolk au
# saint george bm
# busselton au
# bengkulu id
# gavirate it
# puerto ayora ec
# bambous virieux mu
# kapaa us
# vaini to
# busselton au
# mataura pf
# novikovo ru
# port alfred za
# torbay ca
# leningradskiy ru
# kavaratti in
# namibe ao
# panorama br
# marsta se
# tuatapere nz
# fairbanks us
# atambua id
# ukiah us
# coquimbo cl
# mys shmidta ru
# hermanus za
# tubruq ly
# albany au
# arraial do cabo br
# punta arenas cl
# tuktoyaktuk ca
# mataura pf
# andreapol ru
# biltine td
# yulara au
# dromolaxia cy
# hobart au
# dingle ie
# hilo us
# tamworth au
# komsomolskiy ru
# fortuna us
# puerto ayora ec
# ushuaia ar
# bredasdorp za
# ushuaia ar
# hermanus za
# ponta delgada pt
# romitan uz
# albany au
# ampanihy mg
# yulara au
# albany au
# bluff nz
# faanui pf
# chokurdakh ru
# ormara pk
# goderich sl
# brae gb
# mayo ca
# norman wells ca
# ushuaia ar
# busselton au
# padang id

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 602

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1de3eca7c9b6dc3549692c1ffa1238c9

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"
print(city_url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1de3eca7c9b6dc3549692c1ffa1238c9&q=Boston

# %%
# Make a 'Get' request for the city weather.
city_weather = requests.get(city_url)
city_weather
# Out:
# <Response [200]>

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Bston"
city_weather = requests.get(city_url)
city_weather
# Out:
# <Response [404]>

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"
city_weather = requests.get(city_url)
city_weather
# Out:
# <Response [200]>

# %%
# Get the JSON text of the 'Get' request.
city_weather.json()
# Out:
# {'coord': {'lon': -71.0598, 'lat': 42.3584},
#  'weather': [{'id': 803,
#    'main': 'Clouds',
#    'description': 'broken clouds',
#    'icon': '04n'}],
#  'base': 'stations',
#  'main': {'temp': 71.06,
#   'feels_like': 72.05,
#   'temp_min': 68.7,
#   'temp_max': 73.49,
#   'pressure': 1011,
#   'humidity': 89},
#  'visibility': 10000,
#  'wind': {'speed': 3, 'deg': 0, 'gust': 10},
#  'clouds': {'all': 75},
#  'dt': 1627261528,
#  'sys': {'type': 2,
#   'id': 2013408,
#   'country': 'US',
#   'sunrise': 1627205395,
#   'sunset': 1627258279},
#  'timezone': -14400,
#  'id': 4930956,
#  'name': 'Boston',
#  'cod': 200}

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"
city_weather = requests.get(city_url)
if city_weather.status_code == 200:
    print(f"City Weather found.")
else:
    print(f"City weather not found.")
# Out:
# City Weather found.

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"
city_weather = requests.get(city_url)
if city_weather.json():
    print(f"City Weather found.")
else:
    print(f"City weather not found.")
# Out:
# City Weather found.

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"
city_weather = requests.get(city_url)
city_weather.json()
# Out:
# {'coord': {'lon': -71.0598, 'lat': 42.3584},
#  'weather': [{'id': 803,
#    'main': 'Clouds',
#    'description': 'broken clouds',
#    'icon': '04n'}],
#  'base': 'stations',
#  'main': {'temp': 71.06,
#   'feels_like': 72.05,
#   'temp_min': 68.7,
#   'temp_max': 73.49,
#   'pressure': 1011,
#   'humidity': 89},
#  'visibility': 10000,
#  'wind': {'speed': 3, 'deg': 0, 'gust': 10},
#  'clouds': {'all': 75},
#  'dt': 1627261528,
#  'sys': {'type': 2,
#   'id': 2013408,
#   'country': 'US',
#   'sunrise': 1627205395,
#   'sunset': 1627258279},
#  'timezone': -14400,
#  'id': 4930956,
#  'name': 'Boston',
#  'cod': 200}

# %%
# Get the JSON data.
boston_data["sys"]["country"] = city_weather.json()

# %%
boston_data["dt"]
# Out:
# 1627261528

# %%
boston_data["coord"]["lat"]
# Out:
# 42.3584

# %%
boston_data["main"]["temp_max"]
# Out:
# 73.49

# %%
lat = boston_data["coord"]["lat"]
lng = boston_data["coord"]["lon"]
max_temp = boston_data["main"]["temp_max"]
humidity = boston_data["main"]["humidity"]
clouds = boston_data["clouds"]["all"]
wind = boston_data["wind"]["speed"]
print(lat, lng, max_temp, humidity, clouds, wind)
# Out:
# 42.3584 -71.0598 73.49 89 75 3

# %%
# Import the datetime module from the datetime library.
from datetime import datetime
# Get the date from the JSON file.
date = boston_data["dt"]
# Convert the UTC date to a date format with year, month, day, hours, minutes, and seconds.
datetime.utcfromtimestamp(date)
# Out:
# datetime.datetime(2021, 7, 26, 1, 5, 28)

# %%
datetime.utcfromtimestamp(date).strftime('%Y-%m-%d %H:%M:%S')
# Out:
# '2021-07-26 01:05:28'

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | loksa
# Processing Record 2 of Set 1 | zheleznodorozhnyy
# Processing Record 3 of Set 1 | butaritari
# Processing Record 4 of Set 1 | ushtobe
# Processing Record 5 of Set 1 | sambava
# Processing Record 6 of Set 1 | nikolskoye
# Processing Record 7 of Set 1 | riberalta
# Processing Record 8 of Set 1 | hobart
# Processing Record 9 of Set 1 | mataura
# Processing Record 10 of Set 1 | bethel
# Processing Record 11 of Set 1 | rikitea
# Processing Record 12 of Set 1 | ust-ilimsk
# Processing Record 13 of Set 1 | nakhon si thammarat
# Processing Record 14 of Set 1 | bambous virieux
# Processing Record 15 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 16 of Set 1 | ushuaia
# Processing Record 17 of Set 1 | la ronge
# Processing Record 18 of Set 1 | saint-philippe
# Processing Record 19 of Set 1 | novikovo
# Processing Record 20 of Set 1 | puerto ayora
# Processing Record 21 of Set 1 | cape town
# Processing Record 22 of Set 1 | bengkulu
# Processing Record 23 of Set 1 | ribeira grande
# Processing Record 24 of Set 1 | butembo
# Processing Record 25 of Set 1 | ponta do sol
# Processing Record 26 of Set 1 | anadyr
# Processing Record 27 of Set 1 | nome
# Processing Record 28 of Set 1 | qaanaaq
# Processing Record 29 of Set 1 | alta floresta
# Processing Record 30 of Set 1 | iqaluit
# Processing Record 31 of Set 1 | carnarvon
# Processing Record 32 of Set 1 | kismayo
# Processing Record 33 of Set 1 | albany
# Processing Record 34 of Set 1 | arman
# Processing Record 35 of Set 1 | chokurdakh
# Processing Record 36 of Set 1 | santa maria
# Processing Record 37 of Set 1 | vallenar
# Processing Record 38 of Set 1 | vigrestad
# Processing Record 39 of Set 1 | corpus christi
# Processing Record 40 of Set 1 | lebu
# Processing Record 41 of Set 1 | new norfolk
# Processing Record 42 of Set 1 | sabzevar
# Processing Record 43 of Set 1 | pasni
# Processing Record 44 of Set 1 | deputatskiy
# Processing Record 45 of Set 1 | hithadhoo
# Processing Record 46 of Set 1 | marsh harbour
# Processing Record 47 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 48 of Set 1 | elbistan
# Processing Record 49 of Set 1 | tura
# Processing Record 50 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 1 of Set 2 | kaitangata
# Processing Record 2 of Set 2 | saskylakh
# Processing Record 3 of Set 2 | castro
# Processing Record 4 of Set 2 | katsuura
# Processing Record 5 of Set 2 | kapaa
# Processing Record 6 of Set 2 | klaksvik
# Processing Record 7 of Set 2 | khatanga
# Processing Record 8 of Set 2 | atuona
# Processing Record 9 of Set 2 | bardiyah
# Processing Record 10 of Set 2 | maceio
# Processing Record 11 of Set 2 | georgetown
# Processing Record 12 of Set 2 | cherskiy
# Processing Record 13 of Set 2 | cabedelo
# Processing Record 14 of Set 2 | gosainganj
# Processing Record 15 of Set 2 | ayagoz
# Processing Record 16 of Set 2 | kashi
# Processing Record 17 of Set 2 | shchelyayur
# City not found. Skipping...
# Processing Record 18 of Set 2 | farmington
# Processing Record 19 of Set 2 | cabo san lucas
# Processing Record 20 of Set 2 | port elizabeth
# Processing Record 21 of Set 2 | jamestown
# Processing Record 22 of Set 2 | kaliua
# Processing Record 23 of Set 2 | colesberg
# Processing Record 24 of Set 2 | vaini
# Processing Record 25 of Set 2 | busselton
# Processing Record 26 of Set 2 | dikson
# Processing Record 27 of Set 2 | vung tau
# Processing Record 28 of Set 2 | progreso
# Processing Record 29 of Set 2 | sai buri
# Processing Record 30 of Set 2 | lompoc
# Processing Record 31 of Set 2 | port lincoln
# Processing Record 32 of Set 2 | aljezur
# Processing Record 33 of Set 2 | hay river
# Processing Record 34 of Set 2 | luderitz
# Processing Record 35 of Set 2 | dunedin
# Processing Record 36 of Set 2 | whitehorse
# Processing Record 37 of Set 2 | broken hill
# Processing Record 38 of Set 2 | bluff
# Processing Record 39 of Set 2 | ust-tsilma
# Processing Record 40 of Set 2 | sao filipe
# Processing Record 41 of Set 2 | komsomolskiy
# Processing Record 42 of Set 2 | kodiak
# Processing Record 43 of Set 2 | ulagan
# Processing Record 44 of Set 2 | kamenskoye
# City not found. Skipping...
# Processing Record 45 of Set 2 | victoria
# Processing Record 46 of Set 2 | burica
# City not found. Skipping...
# Processing Record 47 of Set 2 | road town
# Processing Record 48 of Set 2 | jining
# Processing Record 49 of Set 2 | mitsamiouli
# Processing Record 50 of Set 2 | torbay
# Processing Record 1 of Set 3 | tiksi
# Processing Record 2 of Set 3 | turan
# Processing Record 3 of Set 3 | hermanus
# Processing Record 4 of Set 3 | mikhaylovka
# Processing Record 5 of Set 3 | east london
# Processing Record 6 of Set 3 | los llanos de aridane
# Processing Record 7 of Set 3 | kruisfontein
# Processing Record 8 of Set 3 | vostok
# Processing Record 9 of Set 3 | luis correia
# Processing Record 10 of Set 3 | yamethin
# Processing Record 11 of Set 3 | punta arenas
# Processing Record 12 of Set 3 | thinadhoo
# Processing Record 13 of Set 3 | visby
# Processing Record 14 of Set 3 | airai
# Processing Record 15 of Set 3 | barrow
# Processing Record 16 of Set 3 | narsaq
# Processing Record 17 of Set 3 | bac lieu
# Processing Record 18 of Set 3 | bonthe
# Processing Record 19 of Set 3 | pacific grove
# Processing Record 20 of Set 3 | rocha
# Processing Record 21 of Set 3 | misratah
# Processing Record 22 of Set 3 | sena madureira
# Processing Record 23 of Set 3 | tasiilaq
# Processing Record 24 of Set 3 | baykit
# Processing Record 25 of Set 3 | nishihara
# Processing Record 26 of Set 3 | leningradskiy
# Processing Record 27 of Set 3 | arzgir
# Processing Record 28 of Set 3 | bolivar
# Processing Record 29 of Set 3 | homer
# Processing Record 30 of Set 3 | sorong
# Processing Record 31 of Set 3 | sobolevo
# Processing Record 32 of Set 3 | cayenne
# Processing Record 33 of Set 3 | saquena
# Processing Record 34 of Set 3 | bargal
# City not found. Skipping...
# Processing Record 35 of Set 3 | mersing
# Processing Record 36 of Set 3 | zhangjiakou
# Processing Record 37 of Set 3 | guerrero negro
# Processing Record 38 of Set 3 | tondano
# Processing Record 39 of Set 3 | talnakh
# Processing Record 40 of Set 3 | kulhudhuffushi
# Processing Record 41 of Set 3 | thompson
# Processing Record 42 of Set 3 | boa vista
# Processing Record 43 of Set 3 | atar
# Processing Record 44 of Set 3 | katiola
# Processing Record 45 of Set 3 | quelimane
# Processing Record 46 of Set 3 | ekhabi
# Processing Record 47 of Set 3 | norman wells
# Processing Record 48 of Set 3 | tabiauea
# City not found. Skipping...
# Processing Record 49 of Set 3 | majene
# Processing Record 50 of Set 3 | fukue
# Processing Record 1 of Set 4 | avarua
# Processing Record 2 of Set 4 | inta
# Processing Record 3 of Set 4 | port hardy
# Processing Record 4 of Set 4 | paamiut
# Processing Record 5 of Set 4 | mahebourg
# Processing Record 6 of Set 4 | barabinsk
# Processing Record 7 of Set 4 | caravelas
# Processing Record 8 of Set 4 | carutapera
# Processing Record 9 of Set 4 | margate
# Processing Record 10 of Set 4 | provideniya
# Processing Record 11 of Set 4 | launceston
# Processing Record 12 of Set 4 | hilo
# Processing Record 13 of Set 4 | san nicolas
# Processing Record 14 of Set 4 | santa isabel do rio negro
# Processing Record 15 of Set 4 | tungkang
# City not found. Skipping...
# Processing Record 16 of Set 4 | mecca
# Processing Record 17 of Set 4 | horta
# Processing Record 18 of Set 4 | samarai
# Processing Record 19 of Set 4 | innisfail
# Processing Record 20 of Set 4 | dawlatabad
# Processing Record 21 of Set 4 | san carlos
# Processing Record 22 of Set 4 | san patricio
# Processing Record 23 of Set 4 | yellowknife
# Processing Record 24 of Set 4 | mar del plata
# Processing Record 25 of Set 4 | myaundzha
# Processing Record 26 of Set 4 | bredasdorp
# Processing Record 27 of Set 4 | papara
# Processing Record 28 of Set 4 | kahului
# Processing Record 29 of Set 4 | tianpeng
# Processing Record 30 of Set 4 | padang
# Processing Record 31 of Set 4 | gondanglegi
# Processing Record 32 of Set 4 | banda aceh
# Processing Record 33 of Set 4 | daru
# Processing Record 34 of Set 4 | ulladulla
# Processing Record 35 of Set 4 | kaseda
# Processing Record 36 of Set 4 | kaltasy
# Processing Record 37 of Set 4 | lewisporte
# Processing Record 38 of Set 4 | krasnoselkup
# Processing Record 39 of Set 4 | rawson
# Processing Record 40 of Set 4 | chapais
# Processing Record 41 of Set 4 | iranshahr
# Processing Record 42 of Set 4 | erenhot
# Processing Record 43 of Set 4 | whitecourt
# Processing Record 44 of Set 4 | pangnirtung
# Processing Record 45 of Set 4 | dudinka
# Processing Record 46 of Set 4 | tarnos
# Processing Record 47 of Set 4 | mao
# Processing Record 48 of Set 4 | tuktoyaktuk
# Processing Record 49 of Set 4 | dingle
# Processing Record 50 of Set 4 | drayton valley
# Processing Record 1 of Set 5 | aksu
# Processing Record 2 of Set 5 | uthal
# Processing Record 3 of Set 5 | andijon
# Processing Record 4 of Set 5 | jovellanos
# Processing Record 5 of Set 5 | kitimat
# Processing Record 6 of Set 5 | belmonte
# Processing Record 7 of Set 5 | port alfred
# Processing Record 8 of Set 5 | karamea
# City not found. Skipping...
# Processing Record 9 of Set 5 | poltavka
# Processing Record 10 of Set 5 | abha
# Processing Record 11 of Set 5 | coquimbo
# Processing Record 12 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 13 of Set 5 | kibala
# Processing Record 14 of Set 5 | vestmannaeyjar
# Processing Record 15 of Set 5 | luganville
# Processing Record 16 of Set 5 | brza palanka
# Processing Record 17 of Set 5 | umzimvubu
# City not found. Skipping...
# Processing Record 18 of Set 5 | ostrovnoy
# Processing Record 19 of Set 5 | diego de almagro
# Processing Record 20 of Set 5 | namibe
# Processing Record 21 of Set 5 | pisco
# Processing Record 22 of Set 5 | port macquarie
# Processing Record 23 of Set 5 | vikulovo
# Processing Record 24 of Set 5 | vega de alatorre
# Processing Record 25 of Set 5 | kita
# Processing Record 26 of Set 5 | aklavik
# Processing Record 27 of Set 5 | piacabucu
# Processing Record 28 of Set 5 | tevaitoa
# Processing Record 29 of Set 5 | mlalo
# Processing Record 30 of Set 5 | russell
# Processing Record 31 of Set 5 | tifton
# Processing Record 32 of Set 5 | turukhansk
# Processing Record 33 of Set 5 | siniscola
# Processing Record 34 of Set 5 | kalmunai
# Processing Record 35 of Set 5 | taoudenni
# Processing Record 36 of Set 5 | richards bay
# Processing Record 37 of Set 5 | muros
# Processing Record 38 of Set 5 | isangel
# Processing Record 39 of Set 5 | kuytun
# Processing Record 40 of Set 5 | asau
# Processing Record 41 of Set 5 | sao felix do xingu
# Processing Record 42 of Set 5 | kabala
# Processing Record 43 of Set 5 | severo-kurilsk
# Processing Record 44 of Set 5 | saint-chamond
# Processing Record 45 of Set 5 | esperance
# Processing Record 46 of Set 5 | mont-dore
# Processing Record 47 of Set 5 | west wendover
# Processing Record 48 of Set 5 | lagoa
# Processing Record 49 of Set 5 | umm lajj
# Processing Record 50 of Set 5 | ancud
# Processing Record 1 of Set 6 | baie-comeau
# Processing Record 2 of Set 6 | sydney
# Processing Record 3 of Set 6 | jizan
# Processing Record 4 of Set 6 | blackwater
# Processing Record 5 of Set 6 | chipinge
# Processing Record 6 of Set 6 | tiznit
# Processing Record 7 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 8 of Set 6 | esso
# Processing Record 9 of Set 6 | hobyo
# Processing Record 10 of Set 6 | amqui
# Processing Record 11 of Set 6 | filadelfia
# Processing Record 12 of Set 6 | husavik
# Processing Record 13 of Set 6 | clyde river
# Processing Record 14 of Set 6 | constitucion
# Processing Record 15 of Set 6 | porto velho
# Processing Record 16 of Set 6 | udachnyy
# Processing Record 17 of Set 6 | kavaratti
# Processing Record 18 of Set 6 | iralaya
# Processing Record 19 of Set 6 | fortuna
# Processing Record 20 of Set 6 | berbera
# Processing Record 21 of Set 6 | palmer
# Processing Record 22 of Set 6 | rock sound
# Processing Record 23 of Set 6 | menomonie
# Processing Record 24 of Set 6 | praia
# Processing Record 25 of Set 6 | vardo
# Processing Record 26 of Set 6 | nizhniy baskunchak
# Processing Record 27 of Set 6 | fare
# Processing Record 28 of Set 6 | vidim
# Processing Record 29 of Set 6 | kuah
# Processing Record 30 of Set 6 | tumannyy
# City not found. Skipping...
# Processing Record 31 of Set 6 | savannah bight
# Processing Record 32 of Set 6 | sioux lookout
# Processing Record 33 of Set 6 | victoria point
# Processing Record 34 of Set 6 | laranjeiras do sul
# Processing Record 35 of Set 6 | saleaula
# City not found. Skipping...
# Processing Record 36 of Set 6 | belaya gora
# Processing Record 37 of Set 6 | bundaberg
# Processing Record 38 of Set 6 | alyangula
# Processing Record 39 of Set 6 | longyearbyen
# Processing Record 40 of Set 6 | kotka
# Processing Record 41 of Set 6 | verkhniy rohachyk
# Processing Record 42 of Set 6 | acapulco
# Processing Record 43 of Set 6 | bur gabo
# City not found. Skipping...
# Processing Record 44 of Set 6 | grindavik
# Processing Record 45 of Set 6 | barentsburg
# City not found. Skipping...
# Processing Record 46 of Set 6 | mogadishu
# Processing Record 47 of Set 6 | verkhnevilyuysk
# Processing Record 48 of Set 6 | lorengau
# Processing Record 49 of Set 6 | praia da vitoria
# Processing Record 50 of Set 6 | bremerton
# Processing Record 1 of Set 7 | taseyevo
# Processing Record 2 of Set 7 | smithers
# Processing Record 3 of Set 7 | huarmey
# Processing Record 4 of Set 7 | beringovskiy
# Processing Record 5 of Set 7 | dicabisagan
# Processing Record 6 of Set 7 | marcona
# City not found. Skipping...
# Processing Record 7 of Set 7 | ketchikan
# Processing Record 8 of Set 7 | almaznyy
# Processing Record 9 of Set 7 | salalah
# Processing Record 10 of Set 7 | haimen
# Processing Record 11 of Set 7 | barbar
# City not found. Skipping...
# Processing Record 12 of Set 7 | daokou
# Processing Record 13 of Set 7 | qui nhon
# Processing Record 14 of Set 7 | timberlake
# Processing Record 15 of Set 7 | hendijan
# City not found. Skipping...
# Processing Record 16 of Set 7 | palpa
# Processing Record 17 of Set 7 | makakilo city
# Processing Record 18 of Set 7 | binzhou
# Processing Record 19 of Set 7 | nynashamn
# Processing Record 20 of Set 7 | geraldton
# Processing Record 21 of Set 7 | griffith
# Processing Record 22 of Set 7 | hasaki
# Processing Record 23 of Set 7 | avera
# Processing Record 24 of Set 7 | wilmington
# Processing Record 25 of Set 7 | mount isa
# Processing Record 26 of Set 7 | arraial do cabo
# Processing Record 27 of Set 7 | zhigansk
# Processing Record 28 of Set 7 | grand river south east
# City not found. Skipping...
# Processing Record 29 of Set 7 | faanui
# Processing Record 30 of Set 7 | antofagasta
# Processing Record 31 of Set 7 | half moon bay
# Processing Record 32 of Set 7 | amfiklia
# Processing Record 33 of Set 7 | touros
# Processing Record 34 of Set 7 | belushya guba
# City not found. Skipping...
# Processing Record 35 of Set 7 | puerto rondon
# Processing Record 36 of Set 7 | wajir
# Processing Record 37 of Set 7 | nizhniy tsasuchey
# Processing Record 38 of Set 7 | flinders
# Processing Record 39 of Set 7 | bubaque
# Processing Record 40 of Set 7 | tautira
# Processing Record 41 of Set 7 | pevek
# Processing Record 42 of Set 7 | kyabe
# Processing Record 43 of Set 7 | guiyang
# Processing Record 44 of Set 7 | bognor regis
# Processing Record 45 of Set 7 | sentyabrskiy
# City not found. Skipping...
# Processing Record 46 of Set 7 | tibacuy
# Processing Record 47 of Set 7 | tucuma
# Processing Record 48 of Set 7 | broome
# Processing Record 49 of Set 7 | upernavik
# Processing Record 50 of Set 7 | chuy
# Processing Record 1 of Set 8 | darnah
# Processing Record 2 of Set 8 | borzya
# Processing Record 3 of Set 8 | nouadhibou
# Processing Record 4 of Set 8 | kasiri
# Processing Record 5 of Set 8 | kudahuvadhoo
# Processing Record 6 of Set 8 | comodoro rivadavia
# Processing Record 7 of Set 8 | lanxi
# Processing Record 8 of Set 8 | mandera
# Processing Record 9 of Set 8 | antalaha
# Processing Record 10 of Set 8 | neustrelitz
# Processing Record 11 of Set 8 | ocho rios
# Processing Record 12 of Set 8 | college
# Processing Record 13 of Set 8 | pak phanang
# Processing Record 14 of Set 8 | la palma
# Processing Record 15 of Set 8 | amapa
# Processing Record 16 of Set 8 | domna
# Processing Record 17 of Set 8 | port hawkesbury
# Processing Record 18 of Set 8 | nizhneyansk
# City not found. Skipping...
# Processing Record 19 of Set 8 | bacolod
# Processing Record 20 of Set 8 | festus
# Processing Record 21 of Set 8 | ordubad
# Processing Record 22 of Set 8 | naron
# Processing Record 23 of Set 8 | hirara
# Processing Record 24 of Set 8 | saint-leu
# Processing Record 25 of Set 8 | lardos
# Processing Record 26 of Set 8 | hof
# Processing Record 27 of Set 8 | odweyne
# Processing Record 28 of Set 8 | sibolga
# Processing Record 29 of Set 8 | iwanai
# Processing Record 30 of Set 8 | ahuimanu
# Processing Record 31 of Set 8 | bafoulabe
# Processing Record 32 of Set 8 | bella union
# Processing Record 33 of Set 8 | puerto lempira
# Processing Record 34 of Set 8 | tamandare
# Processing Record 35 of Set 8 | jaciara
# Processing Record 36 of Set 8 | manacapuru
# Processing Record 37 of Set 8 | sinegorye
# Processing Record 38 of Set 8 | shenjiamen
# Processing Record 39 of Set 8 | camacha
# Processing Record 40 of Set 8 | cabras
# Processing Record 41 of Set 8 | mawlaik
# Processing Record 42 of Set 8 | ahipara
# Processing Record 43 of Set 8 | blagodatnoye
# Processing Record 44 of Set 8 | kushiro
# Processing Record 45 of Set 8 | dentsville
# Processing Record 46 of Set 8 | egvekinot
# Processing Record 47 of Set 8 | port hedland
# Processing Record 48 of Set 8 | rassvet
# Processing Record 49 of Set 8 | kaeo
# Processing Record 50 of Set 8 | shahrud
# Processing Record 1 of Set 9 | lishu
# Processing Record 2 of Set 9 | wabag
# Processing Record 3 of Set 9 | manjakandriana
# Processing Record 4 of Set 9 | sisimiut
# Processing Record 5 of Set 9 | harindanga
# Processing Record 6 of Set 9 | shimoda
# Processing Record 7 of Set 9 | bagotville
# Processing Record 8 of Set 9 | yayva
# Processing Record 9 of Set 9 | keti bandar
# Processing Record 10 of Set 9 | awjilah
# Processing Record 11 of Set 9 | surt
# Processing Record 12 of Set 9 | sawakin
# Processing Record 13 of Set 9 | warqla
# City not found. Skipping...
# Processing Record 14 of Set 9 | poum
# Processing Record 15 of Set 9 | hailar
# Processing Record 16 of Set 9 | kamen-rybolov
# Processing Record 17 of Set 9 | phan rang
# City not found. Skipping...
# Processing Record 18 of Set 9 | marataizes
# Processing Record 19 of Set 9 | bonavista
# Processing Record 20 of Set 9 | coahuayana
# Processing Record 21 of Set 9 | funehiki
# Processing Record 22 of Set 9 | kidal
# Processing Record 23 of Set 9 | guadalupe y calvo
# Processing Record 24 of Set 9 | tazovskiy
# Processing Record 25 of Set 9 | raja jang
# Processing Record 26 of Set 9 | pakhni
# Processing Record 27 of Set 9 | tilichiki
# Processing Record 28 of Set 9 | bay roberts
# Processing Record 29 of Set 9 | yulara
# Processing Record 30 of Set 9 | sheregesh
# Processing Record 31 of Set 9 | zhumadian
# Processing Record 32 of Set 9 | shelburne
# Processing Record 33 of Set 9 | botou
# Processing Record 34 of Set 9 | mgandu
# Processing Record 35 of Set 9 | palabuhanratu
# City not found. Skipping...
# Processing Record 36 of Set 9 | sibu
# Processing Record 37 of Set 9 | xunchang
# Processing Record 38 of Set 9 | guarda
# Processing Record 39 of Set 9 | kysyl-syr
# Processing Record 40 of Set 9 | voh
# Processing Record 41 of Set 9 | klyuchi
# Processing Record 42 of Set 9 | buraydah
# Processing Record 43 of Set 9 | tikrit
# Processing Record 44 of Set 9 | gusinoye ozero
# Processing Record 45 of Set 9 | westport
# Processing Record 46 of Set 9 | durazno
# Processing Record 47 of Set 9 | tocopilla
# Processing Record 48 of Set 9 | swellendam
# Processing Record 49 of Set 9 | pishva
# Processing Record 50 of Set 9 | leshukonskoye
# Processing Record 1 of Set 10 | north bend
# Processing Record 2 of Set 10 | galiwinku
# City not found. Skipping...
# Processing Record 3 of Set 10 | haradok
# Processing Record 4 of Set 10 | wiwili
# Processing Record 5 of Set 10 | faya
# Processing Record 6 of Set 10 | san jose
# Processing Record 7 of Set 10 | middletown
# Processing Record 8 of Set 10 | chernyshevskiy
# Processing Record 9 of Set 10 | meulaboh
# Processing Record 10 of Set 10 | grand gaube
# Processing Record 11 of Set 10 | karaul
# City not found. Skipping...
# Processing Record 12 of Set 10 | luanda
# Processing Record 13 of Set 10 | saldanha
# Processing Record 14 of Set 10 | yar-sale
# Processing Record 15 of Set 10 | zhicheng
# Processing Record 16 of Set 10 | mercedes
# Processing Record 17 of Set 10 | almeirim
# Processing Record 18 of Set 10 | nyurba
# Processing Record 19 of Set 10 | riyadh
# Processing Record 20 of Set 10 | burnie
# Processing Record 21 of Set 10 | noumea
# Processing Record 22 of Set 10 | melilla
# Processing Record 23 of Set 10 | derzhavinsk
# Processing Record 24 of Set 10 | kamsack
# Processing Record 25 of Set 10 | sungairaya
# Processing Record 26 of Set 10 | liku
# Processing Record 27 of Set 10 | atbasar
# Processing Record 28 of Set 10 | pankrushikha
# Processing Record 29 of Set 10 | srednekolymsk
# Processing Record 30 of Set 10 | adrar
# Processing Record 31 of Set 10 | lata
# Processing Record 32 of Set 10 | uribia
# Processing Record 33 of Set 10 | oktyabrskiy
# Processing Record 34 of Set 10 | scarborough
# Processing Record 35 of Set 10 | araouane
# Processing Record 36 of Set 10 | skagastrond
# City not found. Skipping...
# Processing Record 37 of Set 10 | kemijarvi
# Processing Record 38 of Set 10 | eureka
# Processing Record 39 of Set 10 | angoche
# Processing Record 40 of Set 10 | tsihombe
# City not found. Skipping...
# Processing Record 41 of Set 10 | kazalinsk
# City not found. Skipping...
# Processing Record 42 of Set 10 | nizhnyaya poyma
# Processing Record 43 of Set 10 | kuhdasht
# Processing Record 44 of Set 10 | kara-tyube
# Processing Record 45 of Set 10 | mandalgovi
# Processing Record 46 of Set 10 | yeppoon
# Processing Record 47 of Set 10 | laguna
# Processing Record 48 of Set 10 | paranaiba
# Processing Record 49 of Set 10 | biak
# Processing Record 50 of Set 10 | bajo baudo
# City not found. Skipping...
# Processing Record 1 of Set 11 | kambove
# Processing Record 2 of Set 11 | omboue
# Processing Record 3 of Set 11 | hamilton
# Processing Record 4 of Set 11 | ilulissat
# Processing Record 5 of Set 11 | wairoa
# Processing Record 6 of Set 11 | el badari
# City not found. Skipping...
# Processing Record 7 of Set 11 | san cristobal
# Processing Record 8 of Set 11 | tucumcari
# Processing Record 9 of Set 11 | kungurtug
# Processing Record 10 of Set 11 | kavieng
# Processing Record 11 of Set 11 | rawannawi
# City not found. Skipping...
# Processing Record 12 of Set 11 | saint-georges
# Processing Record 13 of Set 11 | kendari
# Processing Record 14 of Set 11 | bremervorde
# Processing Record 15 of Set 11 | vanderhoof
# Processing Record 16 of Set 11 | kununurra
# Processing Record 17 of Set 11 | olinda
# Processing Record 18 of Set 11 | san carlos de bariloche
# Processing Record 19 of Set 11 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 20 of Set 11 | methoni
# Processing Record 21 of Set 11 | genhe
# Processing Record 22 of Set 11 | gornoye loo
# Processing Record 23 of Set 11 | bonfim
# Processing Record 24 of Set 11 | dekar
# Processing Record 25 of Set 11 | kadoma
# Processing Record 26 of Set 11 | biltine
# Processing Record 27 of Set 11 | marv dasht
# City not found. Skipping...
# Processing Record 28 of Set 11 | riachao
# Processing Record 29 of Set 11 | mayo
# Processing Record 30 of Set 11 | baglung
# Processing Record 31 of Set 11 | sistranda
# Processing Record 32 of Set 11 | hambantota
# Processing Record 33 of Set 11 | namwala
# Processing Record 34 of Set 11 | etchoropo
# Processing Record 35 of Set 11 | skalistyy
# City not found. Skipping...
# Processing Record 36 of Set 11 | vaitupu
# City not found. Skipping...
# Processing Record 37 of Set 11 | sola
# Processing Record 38 of Set 11 | hun
# Processing Record 39 of Set 11 | mehamn
# Processing Record 40 of Set 11 | estelle
# Processing Record 41 of Set 11 | nabire
# Processing Record 42 of Set 11 | changji
# Processing Record 43 of Set 11 | havoysund
# Processing Record 44 of Set 11 | moranbah
# Processing Record 45 of Set 11 | quatre cocos
# Processing Record 46 of Set 11 | healesville
# Processing Record 47 of Set 11 | arrifes
# Processing Record 48 of Set 11 | yazman
# Processing Record 49 of Set 11 | solsvik
# City not found. Skipping...
# Processing Record 50 of Set 11 | ruteng
# Processing Record 1 of Set 12 | koslan
# Processing Record 2 of Set 12 | itaituba
# Processing Record 3 of Set 12 | ballina
# Processing Record 4 of Set 12 | fallon
# Processing Record 5 of Set 12 | saint-pierre
# Processing Record 6 of Set 12 | rio grande
# Processing Record 7 of Set 12 | bayaguana
# Processing Record 8 of Set 12 | sangar
# Processing Record 9 of Set 12 | batticaloa
# Processing Record 10 of Set 12 | makasar
# Processing Record 11 of Set 12 | sassandra
# Processing Record 12 of Set 12 | zhezkazgan
# Processing Record 13 of Set 12 | hervey bay
# Processing Record 14 of Set 12 | tuatapere
# Processing Record 15 of Set 12 | auch
# Processing Record 16 of Set 12 | necochea
# Processing Record 17 of Set 12 | inhambane
# Processing Record 18 of Set 12 | aras
# Processing Record 19 of Set 12 | alofi
# Processing Record 20 of Set 12 | mayahi
# Processing Record 21 of Set 12 | vila velha
# Processing Record 22 of Set 12 | shahdadkot
# Processing Record 23 of Set 12 | braslav
# City not found. Skipping...
# Processing Record 24 of Set 12 | severobaykalsk
# Processing Record 25 of Set 12 | tual
# Processing Record 26 of Set 12 | algiers
# Processing Record 27 of Set 12 | bandar
# Processing Record 28 of Set 12 | dodoma
# Processing Record 29 of Set 12 | vao
# Processing Record 30 of Set 12 | stornoway
# Processing Record 31 of Set 12 | roma
# Processing Record 32 of Set 12 | buta
# Processing Record 33 of Set 12 | fort nelson
# Processing Record 34 of Set 12 | naze
# Processing Record 35 of Set 12 | pojuca
# Processing Record 36 of Set 12 | saint george
# Processing Record 37 of Set 12 | gavirate
# Processing Record 38 of Set 12 | panorama
# Processing Record 39 of Set 12 | marsta
# Processing Record 40 of Set 12 | fairbanks
# Processing Record 41 of Set 12 | atambua
# Processing Record 42 of Set 12 | ukiah
# Processing Record 43 of Set 12 | tubruq
# City not found. Skipping...
# Processing Record 44 of Set 12 | andreapol
# Processing Record 45 of Set 12 | dromolaxia
# Processing Record 46 of Set 12 | tamworth
# Processing Record 47 of Set 12 | ponta delgada
# Processing Record 48 of Set 12 | romitan
# Processing Record 49 of Set 12 | ampanihy
# Processing Record 50 of Set 12 | ormara
# Processing Record 1 of Set 13 | goderich
# Processing Record 2 of Set 13 | brae
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0              Loksa  59.5764   25.7214     55.72        72          12
# 1  Zheleznodorozhnyy  55.7503   38.0042     61.14        56          39
# 2         Butaritari   3.0707  172.7902     79.97        84          98
# 3            Ushtobe  45.2514   77.9838     80.96        20           0
# 4            Sambava -14.2667   50.1667     65.41        84           4
# 5         Nikolskoye  59.7035   30.7861     63.81        62          98
# 6          Riberalta -10.9833  -66.1000     80.91        47          82
# 7             Hobart -42.8794  147.3294     53.46        65          40
# 8            Mataura -46.1927  168.8643     48.47        87         100
# 9             Bethel  41.3712  -73.4140     75.49        89           0
#
#    Wind Speed Country                 Date
# 0        5.01      EE  2021-07-26 01:25:25
# 1        2.04      RU  2021-07-26 01:25:25
# 2       13.91      KI  2021-07-26 01:25:26
# 3        4.50      KZ  2021-07-26 01:25:26
# 4       12.08      MG  2021-07-26 01:25:26
# 5        4.45      RU  2021-07-26 01:25:27
# 6        2.75      BO  2021-07-26 01:23:44
# 7        1.01      AU  2021-07-26 01:25:27
# 8        2.24      NZ  2021-07-26 01:25:28
# 9        2.98      US  2021-07-26 01:25:28

# %%
# Create the output file (CSV).
output_data_file = (r"C:\Users\reske\Documents\Data Analysis Bootcamp\Week 6\World_Weather_Analysis\weather_data\cities.csv")
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")

# %%
# Extract relevant fields from the DataFrame for plotting.
lats = city_data_df["Lat"]
max_temps = city_data_df["Max Temp"]
humidity = city_data_df["Humidity"]
cloudiness = city_data_df["Cloudiness"]
wind_speed = city_data_df["Wind Speed"]

# %%
# Import the time module.
import time
# Get today's date in seconds.
today = time.time()
today
# Out:
# 1627263805.8302486

# %%
# Import time module
import time

# Build the scatter plot for latitude vs. max temperature.
plt.scatter(lats,
            max_temps,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Max Temperature "+ time.strftime("%x"))
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure.
plt.savefig(r"C:\Users\reske\Documents\Data Analysis Bootcamp\Week 6\World_Weather_Analysis\weather_data\Fig1.png")

# Show plot.
plt.show()

# %%
# Build the scatter plots for latitude vs. humidity.
plt.scatter(lats,
            humidity,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Humidity "+ time.strftime("%x"))
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig(r"C:\Users\reske\Documents\Data Analysis Bootcamp\Week 6\World_Weather_Analysis\weather_data\Fig2.png")
# Show plot.
plt.show()

# %%
# Build the scatter plots for latitude vs. cloudiness.
plt.scatter(lats,
            cloudiness,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Cloudiness (%) "+ time.strftime("%x"))
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig3.png")
# Show plot.
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-52-71ad295a9d07> in <module>
#      11 plt.grid(True)
#      12 # Save the figure.
# ---> 13 plt.savefig("weather_data/Fig3.png")
#      14 # Show plot.
#      15 plt.show()
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\matplotlib\pyplot.py in savefig(*args, **kwargs)
#     857 def savefig(*args, **kwargs):
#     858     fig = gcf()
# --> 859     res = fig.savefig(*args, **kwargs)
#     860     fig.canvas.draw_idle()   # need this if 'transparent=True' to reset colors
#     861     return res
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\matplotlib\figure.py in savefig(self, fname, transparent, **kwargs)
#    2309                 patch.set_edgecolor('none')
#    2310
# -> 2311         self.canvas.print_figure(fname, **kwargs)
#    2312
#    2313         if transparent:
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\matplotlib\backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2215                     orientation=orientation,
#    2216                     bbox_inches_restore=_bbox_inches_restore,
# -> 2217                     **kwargs)
#    2218             finally:
#    2219                 if bbox_inches and restore_bbox:
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\matplotlib\backend_bases.py in wrapper(*args, **kwargs)
#    1637             kwargs.pop(arg)
#    1638
# -> 1639         return func(*args, **kwargs)
#    1640
#    1641     return wrapper
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\matplotlib\backends\backend_agg.py in print_png(self, filename_or_obj, metadata, pil_kwargs, *args)
#     510         mpl.image.imsave(
#     511             filename_or_obj, self.buffer_rgba(), format="png", origin="upper",
# --> 512             dpi=self.figure.dpi, metadata=metadata, pil_kwargs=pil_kwargs)
#     513
#     514     def print_to_buffer(self):
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\matplotlib\image.py in imsave(fname, arr, vmin, vmax, cmap, format, origin, dpi, metadata, pil_kwargs)
#    1609         pil_kwargs.setdefault("format", format)
#    1610         pil_kwargs.setdefault("dpi", (dpi, dpi))
# -> 1611         image.save(fname, **pil_kwargs)
#    1612
#    1613
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\PIL\Image.py in save(self, fp, format, **params)
#    2167                 fp = builtins.open(filename, "r+b")
#    2168             else:
# -> 2169                 fp = builtins.open(filename, "w+b")
#    2170
#    2171         try:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'weather_data/Fig3.png'
